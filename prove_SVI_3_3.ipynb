# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch as th
import pyro
import pyro.distributions as dist
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import RandomOverSampler
from torch.distributions import constraints
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("/home/gabriel/Documents/PBML/diabetes.csv")

X = df.drop("Outcome", axis=1)  # split between variables and target
y = df.loc[:, 'Outcome']

over_sampler = RandomOverSampler(random_state=1234)  # balancing the data with over sampling
X, y = over_sampler.fit_resample(X, y)

# Apply Min-Max scaling to X
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X = X.to_numpy()  # convert to numpy array
y = y.to_numpy()

X = th.tensor(X, dtype=th.float32)
y = th.tensor(y, dtype=th.float32)

# Define the Bayesian logistic regression model. Priors have been chosen from a previously run MCMC model
def model(X, y):
    b = pyro.sample('b', dist.Normal(-5.47, 0.53))
    w1 = pyro.sample('w1', dist.Normal(0.12, 0.03))
    w2 = pyro.sample('w2', dist.Normal(0.03, 0.01))
    w3 = pyro.sample('w3', dist.Normal(-0.02, 0.01))
    w4 = pyro.sample('w4', dist.Normal(0.00, 0.01))
    w5 = pyro.sample('w5', dist.Normal(0.00, 0.01))
    w6 = pyro.sample('w6', dist.Normal(0.06, 0.01))
    w7 = pyro.sample('w7', dist.Normal(0.67, 0.24))
    w8 = pyro.sample('w8', dist.Normal(0.02, 0.01))

    logits = b + w1 * X[:, 0] + w2 * X[:, 1] + w3 * X[:, 2] + w4 * X[:, 3] + w5 * X[:, 4] + w6 * X[:, 5] + w7 * X[:, 6] + w8 * X[:, 7]
    with pyro.plate('data', X.shape[0]):
        pyro.sample('obs', dist.Bernoulli(logits=logits), obs=y)
    return logits

def guide(X, y):
    b_loc = pyro.param('b_loc', th.tensor(-5.47))
    b_scale = pyro.param('b_scale', th.tensor(0.53), constraint=dist.constraints.positive)
    b = pyro.sample('b', dist.Normal(b_loc, b_scale))

    w1_loc = pyro.param('w1_loc', th.tensor(0.12))
    w1_scale = pyro.param('w1_scale', th.tensor(0.03), constraint=dist.constraints.positive)
    w1 = pyro.sample('w1', dist.Normal(b_loc, b_scale))

    w2_loc = pyro.param('w2_loc', th.tensor(0.03))
    w2_scale = pyro.param('w2_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w2 = pyro.sample('w2', dist.Normal(w2_loc, w2_scale))

    w3_loc = pyro.param('w3_loc', th.tensor(-0.02))
    w3_scale = pyro.param('w3_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w3 = pyro.sample('w3', dist.Normal(w3_loc, w3_scale))

    w4_loc = pyro.param('w4_loc', th.tensor(0.00))
    w4_scale = pyro.param('w4_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w4 = pyro.sample('w4', dist.Normal(w4_loc, w4_scale))

    w5_loc = pyro.param('w5_loc', th.tensor(0.00))
    w5_scale = pyro.param('w5_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w5 = pyro.sample('w5', dist.Normal(w5_loc, w5_scale))

    w6_loc = pyro.param('w6_loc', th.tensor(0.06))
    w6_scale = pyro.param('w6_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w6 = pyro.sample('w6', dist.Normal(w6_loc, w6_scale))

    w7_loc = pyro.param('w7_loc', th.tensor(0.67))
    w7_scale = pyro.param('w7_scale', th.tensor(0.24), constraint=dist.constraints.positive)
    w7 = pyro.sample('w7', dist.Normal(w7_loc, w7_scale))

    w8_loc = pyro.param('w8_loc', th.tensor(0.02))
    w8_scale = pyro.param('w8_scale', th.tensor(0.01), constraint=dist.constraints.positive)
    w8 = pyro.sample('w8', dist.Normal(w8_loc, w8_scale))

    return th.sigmoid(b + w1 * X[:, 0] + w2 * X[:, 1] + w3 * X[:, 2] + w4 * X[:, 3] + w5 * X[:, 4] + w6 * X[:, 5] + w7 * X[:, 6] + w8 * X[:, 7])


elbo_values = []  # List to store ELBO values for the current fold

# Initialize the SVI object with the model, guide, optimizer, and loss function
svi = SVI(model, guide, Adam({}), loss=Trace_ELBO())

loss = []
num_iters = 15000

num_folds = 5  # number of cross-validation folds
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
sensitivities = []
specificities = []

for train_indices, test_indices in skf.split(X, y):
    X_train, X_test = X[train_indices], X[test_indices]
    y_train, y_test = y[train_indices], y[test_indices]

    # Clear the parameter store for each fold
    pyro.clear_param_store()
    
    elbo_values_fold = []  # List to store ELBO values for the current fold
    
    for i in range(num_iters):
        elbo = svi.step(X_train, y_train)  # Calculate ELBO for each step
        elbo_values_fold.append(elbo)  # Append the ELBO value to the list

    elbo_values.append(elbo_values_fold)  # Append the fold-specific ELBO values to the main list

    predicted_probs = guide(X_test, None)  # compute predictions over test set
    predicted_labels = (predicted_probs > 0.5).float()  # predictions with probabilities over 0.5 are positive
    cm = confusion_matrix(y_test, predicted_labels)  # create confusion matrix
    # Extract true positive, true negative, false positive, and false negative from confusion matrix
    tn, fp, fn, tp = cm.ravel()

    # Calculate sensitivity and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)

    sensitivities.append(sensitivity)
    specificities.append(specificity)

# Calculate mean and standard deviation of sensitivity and specificity
mean_sensitivity = np.mean(sensitivities)
std_sensitivity = np.std(sensitivities)
mean_specificity = np.mean(specificities)
std_specificity = np.std(specificities)

# Print mean and standard deviation of sensitivity and specificity
print("Mean Sensitivity:", mean_sensitivity)
print("Standard Deviation Sensitivity:", std_sensitivity)
print("Mean Specificity:", mean_specificity)
print("Standard Deviation Specificity:", std_specificity)


# Plot the ELBO values for each fold
for i, elbo_values_fold in enumerate(elbo_values):
    plt.plot(elbo_values_fold, label=f"Fold {i+1}")

plt.xlabel("Iteration")
plt.ylabel("ELBO")
plt.title("Convergence of ELBO")
plt.legend()
plt.show()
# Out:
# Mean Sensitivity: 0.616
# Standard Deviation Sensitivity: 0.268
# Mean Specificity: 0.6180000000000001
# Standard Deviation Specificity: 0.21103554203024663

# %%
print(sensitivities)
# Out:
# [0.79, 0.82, 0.59, 0.74, 0.7]

# %%
num_iters = 15000  # number of iterations for training
losses = []  # initialize the list to store losses

for i in range(num_iters):
    loss = svi.step(X_train, y_train)
    losses.append(loss)
    if i % 100 == 0:
        print("Iteration {:>5d} - Loss: {:.4f}".format(i, loss))

# Plot the ELBO loss over iterations
plt.plot(losses)
plt.xlabel("Iteration")
plt.ylabel("ELBO Loss")
plt.title("Convergence Diagnosis")
plt.show()
# Out:
# Iteration     0 - Loss: 581.9690
# Iteration   100 - Loss: 587.6829
# Iteration   200 - Loss: 602.3411
# Iteration   300 - Loss: 580.7588
# Iteration   400 - Loss: 579.3448
# Iteration   500 - Loss: 582.8054
# Iteration   600 - Loss: 586.9952
# Iteration   700 - Loss: 582.7182
# Iteration   800 - Loss: 589.0619
# Iteration   900 - Loss: 583.3051
# Iteration  1000 - Loss: 586.5014
# Iteration  1100 - Loss: 580.5601
# Iteration  1200 - Loss: 588.8039
# Iteration  1300 - Loss: 577.2720
# Iteration  1400 - Loss: 582.0925
# Iteration  1500 - Loss: 593.1580
# Iteration  1600 - Loss: 578.8940
# Iteration  1700 - Loss: 591.0967
# Iteration  1800 - Loss: 587.3831
# Iteration  1900 - Loss: 578.0929
# Iteration  2000 - Loss: 587.2207
# Iteration  2100 - Loss: 604.4011
# Iteration  2200 - Loss: 581.6959
# Iteration  2300 - Loss: 582.5171
# Iteration  2400 - Loss: 581.4879
# Iteration  2500 - Loss: 575.1416
# Iteration  2600 - Loss: 575.3026
# Iteration  2700 - Loss: 580.4837
# Iteration  2800 - Loss: 583.1576
# Iteration  2900 - Loss: 577.9217
# Iteration  3000 - Loss: 589.8592
# Iteration  3100 - Loss: 579.5163
# Iteration  3200 - Loss: 591.4673
# Iteration  3300 - Loss: 580.0416
# Iteration  3400 - Loss: 602.0612
# Iteration  3500 - Loss: 586.4289
# Iteration  3600 - Loss: 574.1825
# Iteration  3700 - Loss: 578.5218
# Iteration  3800 - Loss: 590.7480
# Iteration  3900 - Loss: 576.9885
# Iteration  4000 - Loss: 591.7859
# Iteration  4100 - Loss: 587.7487
# Iteration  4200 - Loss: 573.8970
# Iteration  4300 - Loss: 588.1507
# Iteration  4400 - Loss: 574.9749
# Iteration  4500 - Loss: 577.7883
# Iteration  4600 - Loss: 579.3002
# Iteration  4700 - Loss: 592.5536
# Iteration  4800 - Loss: 577.6020
# Iteration  4900 - Loss: 591.4311
# Iteration  5000 - Loss: 581.7599
# Iteration  5100 - Loss: 572.2317
# Iteration  5200 - Loss: 584.4479
# Iteration  5300 - Loss: 588.1110
# Iteration  5400 - Loss: 583.2794
# Iteration  5500 - Loss: 582.1207
# Iteration  5600 - Loss: 584.8680
# Iteration  5700 - Loss: 589.5319
# Iteration  5800 - Loss: 608.2915
# Iteration  5900 - Loss: 582.1885
# Iteration  6000 - Loss: 577.7550
# Iteration  6100 - Loss: 577.6899
# Iteration  6200 - Loss: 582.5310
# Iteration  6300 - Loss: 577.1422
# Iteration  6400 - Loss: 586.1039
# Iteration  6500 - Loss: 581.6368
# Iteration  6600 - Loss: 581.8331
# Iteration  6700 - Loss: 579.6319
# Iteration  6800 - Loss: 584.3244
# Iteration  6900 - Loss: 576.4521
# Iteration  7000 - Loss: 586.8993
# Iteration  7100 - Loss: 576.8576
# Iteration  7200 - Loss: 585.8224
# Iteration  7300 - Loss: 585.6945
# Iteration  7400 - Loss: 575.6015
# Iteration  7500 - Loss: 601.3516
# Iteration  7600 - Loss: 575.7967
# Iteration  7700 - Loss: 586.1487
# Iteration  7800 - Loss: 578.8889
# Iteration  7900 - Loss: 578.1487
# Iteration  8000 - Loss: 580.5642
# Iteration  8100 - Loss: 593.9431
# Iteration  8200 - Loss: 580.7771
# Iteration  8300 - Loss: 580.4516
# Iteration  8400 - Loss: 578.5237
# Iteration  8500 - Loss: 575.6409
# Iteration  8600 - Loss: 572.6837
# Iteration  8700 - Loss: 581.1516
# Iteration  8800 - Loss: 580.9188
# Iteration  8900 - Loss: 577.5697
# Iteration  9000 - Loss: 580.8300
# Iteration  9100 - Loss: 575.8562
# Iteration  9200 - Loss: 576.2582
# Iteration  9300 - Loss: 601.2171
# Iteration  9400 - Loss: 579.5489
# Iteration  9500 - Loss: 574.7135
# Iteration  9600 - Loss: 577.1670
# Iteration  9700 - Loss: 580.0657
# Iteration  9800 - Loss: 581.4341
# Iteration  9900 - Loss: 577.2432
# Iteration 10000 - Loss: 601.2311
# Iteration 10100 - Loss: 580.7600
# Iteration 10200 - Loss: 585.8211
# Iteration 10300 - Loss: 578.8431
# Iteration 10400 - Loss: 579.9436
# Iteration 10500 - Loss: 575.6090
# Iteration 10600 - Loss: 577.7312
# Iteration 10700 - Loss: 587.4427
# Iteration 10800 - Loss: 579.1008
# Iteration 10900 - Loss: 586.0571
# Iteration 11000 - Loss: 574.2498
# Iteration 11100 - Loss: 581.6196
# Iteration 11200 - Loss: 578.2892
# Iteration 11300 - Loss: 582.0731
# Iteration 11400 - Loss: 580.4326
# Iteration 11500 - Loss: 574.7946
# Iteration 11600 - Loss: 576.1741
# Iteration 11700 - Loss: 581.3526
# Iteration 11800 - Loss: 578.2883
# Iteration 11900 - Loss: 612.4445
# Iteration 12000 - Loss: 591.3010
# Iteration 12100 - Loss: 577.9881
# Iteration 12200 - Loss: 579.7172
# Iteration 12300 - Loss: 592.1988
# Iteration 12400 - Loss: 580.2411
# Iteration 12500 - Loss: 586.4532
# Iteration 12600 - Loss: 598.9993
# Iteration 12700 - Loss: 579.1729
# Iteration 12800 - Loss: 584.1351
# Iteration 12900 - Loss: 596.6265
# Iteration 13000 - Loss: 579.8227
# Iteration 13100 - Loss: 583.4295
# Iteration 13200 - Loss: 580.0382
# Iteration 13300 - Loss: 578.5503
# Iteration 13400 - Loss: 575.9405
# Iteration 13500 - Loss: 580.7532
# Iteration 13600 - Loss: 584.2827
# Iteration 13700 - Loss: 580.5771
# Iteration 13800 - Loss: 576.8397
# Iteration 13900 - Loss: 587.7069
# Iteration 14000 - Loss: 577.9675
# Iteration 14100 - Loss: 582.1685
# Iteration 14200 - Loss: 583.1290
# Iteration 14300 - Loss: 579.3002
# Iteration 14400 - Loss: 572.9231
# Iteration 14500 - Loss: 582.4706
# Iteration 14600 - Loss: 581.1853
# Iteration 14700 - Loss: 579.7903
# Iteration 14800 - Loss: 577.8502
# Iteration 14900 - Loss: 611.4436
